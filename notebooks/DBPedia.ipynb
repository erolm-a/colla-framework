# %%
from tools.datasets import *
from tools.sparql_wrapper import DBPediaQuery

# %%
semweb_df = fetch_dataset("Semantic_Web", "dbpedia")
# Out:
# Dataset Semantic_Web.json already available. Downloading from https://dbpedia.org/data/Semantic_Web.json
# Done

# %%
root = semweb_df["http://dbpedia.org/resource/Semantic_Web"]

# %%
# Until I manage to setup a SPARQL endpoint I'll just work with the dumps I have
import logging

def strip_prefix(prefix: str, payload: str):
    if payload.startswith(prefix):
        return payload[len(prefix):]
    return payload
    
def extract_wikidata_reference(name, df):
    prefix = "http://www.wikidata.org/entity/"
    owl_sameAs = "http://www.w3.org/2002/07/owl#sameAs"
    
    def check(row: pd.Series):
        return row["p.value"] == owl_sameAs and \
                row["o.value"].startswith(prefix + "Q")

    try:
        return strip_prefix(prefix, df[df.apply(check, axis=1)].iloc[0]["o.value"])
    except:
        logging.warn(f"Could not find wikidata entity for entity {name}")

"""
def extract_wikipedia_entity(name):
    # keep it very simple - for now
    name = strip_prefix("http://dbpedia.org/page/", name)
    name = strip_prefix("http://dbpedia.org/resource/", name)
    return "http://wikipedia.org/wiki/" + name

    # TODO: Actually query the dataset to find wikipedia-en:
    
"""

def merge_with_wikidata(name: str):
    # Simple merging algo:
    # For all dbpedia triplets, replace the original resource name with the wikipedia link,
    # Thus query wikidata so that 
    # Then look for a relationship in wikidata that links the very same entities
    # and associate the link to the wikidata property.
    entity_df = fetch_dataset(name, provider='dbpedia')
    wd_id = extract_wikidata_reference(name, entity_df)
    wd_df = fetch_dataset(wd_id, provider='wikidata')

    # Only consider the rows that match with the resource name
    for row in entity_df.iterrows():
        pass

# %%
res = fetch_dataset("Semantic_web", provider="dbpedia")

for row in res.iterrows():
    print(row[1]["s.value"], row[1]["p.value"], row[1]["o.value"])
# Out:
# Dataset not available, downloading from http://dbpedia.org/page/Semantic_web
# /usr/local/lib/python3.7/dist-packages/SPARQLWrapper/Wrapper.py:979: RuntimeWarning: Sending Accept header '*/*' because unexpected returned format 'json' in a 'DESCRIBE' SPARQL query form
#   warnings.warn("Sending Accept header '*/*' because unexpected returned format '%s' in a '%s' SPARQL query form" % (self.returnFormat, self.queryType), RuntimeWarning)
# http://dbpedia.org/resource/Semantic_spectrum http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/List_of_University_of_Maryland,_Baltimore_County_people http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/A.nnotate http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Data_Reference_Model http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Formal_concept_analysis http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Terminology_extraction http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Peter_Fox_(professor) http://dbpedia.org/ontology/field http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Qitera http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/HTML http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Multi-user_MIMO http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Knowledge-based_systems http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Vasant_Honavar http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/HTML_email http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Plant_ontology http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/VOA3R http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Knowledge_Engineering_and_Machine_Learning_Group http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/GNOWSYS http://dbpedia.org/ontology/genre http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Translatewiki.net http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Dieter_Fensel http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/SPARQL http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Universal_Data_Element_Framework http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Social_web http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Donna_Carol_Kurtz http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Compat.egov http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Semantic_warehousing http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://en.wikipedia.org/wiki/Semantic_web http://xmlns.com/foaf/0.1/primaryTopic http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Semantic_technology http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/GNOWSYS http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Prolog http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Pat_Hayes http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Peter_Fox_(professor) http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Regator http://dbpedia.org/ontology/type http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Metadata_publishing http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/International_World_Wide_Web_Conference http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Calais_(Reuters_product) http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Wright_State_University http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Tag_(metadata) http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Logic_in_computer_science http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Exhibit_(web_editing_tool) http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Tool_for_Ontology_Development_and_Editing_(TODE) http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Sesame_(framework) http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Freebase http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Deborah_McGuinness http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/DOAP http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Provenance http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/RuleML_Symposium http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Integrated_Authority_File http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/State_(website) http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Katia_Sycara http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/OMDoc http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Collaborative_network http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/IPlant_Collaborative http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/ChemSpider http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Wired_for_Thought http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Celtrak http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Simple_HTML_Ontology_Extensions http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Semantic_publishing http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Vrije_Universiteit_Amsterdam http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/James_Hendler http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Semantic_web http://xmlns.com/foaf/0.1/isPrimaryTopicOf http://en.wikipedia.org/wiki/Semantic_web
# http://dbpedia.org/resource/CycL http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Intelligence_analysis http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Internet_of_things http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/HTTPRange-14 http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Knowledge-based_engineering http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Image_retrieval http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Semantic_service-oriented_architecture http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Web_content_lifecycle http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/World_Brain http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Semantic_web http://www.w3.org/2000/01/rdf-schema#label Semantic web
# http://dbpedia.org/resource/Nigel_Shadbolt http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Information_extraction http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Dean_Allemang http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Semantic_query http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Service_discovery http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Regator http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Bio2RDF http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Journal_of_Web_Semantics http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Shelley_Powers http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Data_mapping http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Pedagogy_3.0 http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Distinguo http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Gandalf_(theorem_prover) http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Metaclass_(disambiguation) http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Alan_Rector http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Annotation http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/E-democracy http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Reasoning_system http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Semantic_web http://dbpedia.org/ontology/wikiPageRedirects http://dbpedia.org/resource/Semantic_Web
# http://dbpedia.org/resource/Hipertext.net http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Semantic_MediaWiki http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Wendy_Hall http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Intraweb http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Tuple http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Metadata_discovery http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Computer-supported_collaboration http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Text_mining http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Semantic_Sensor_Web http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Inference http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/David_De_Roure http://dbpedia.org/ontology/field http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Cwm_(software) http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Web_intelligence http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Rule_Interchange_Format http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Semantic_web http://dbpedia.org/ontology/wikiPageID 52314
# http://dbpedia.org/resource/Mathematical_knowledge_management http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Datalog http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Tim_Finin http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Applied_ontology http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Semantic_web http://www.w3.org/ns/prov#wasDerivedFrom http://en.wikipedia.org/wiki/Semantic_web?oldid=177677665
# http://dbpedia.org/resource/HTML5 http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/VideoLectures.net http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/David_De_Roure http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Information_science http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Web_annotation http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Trekiz http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Paulo_Pinheiro http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Intelligent_Web_Business_Laboratory http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Daylife http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Data_exchange http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Class_(computer_programming) http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Neuroinformatics http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Semantic_search http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Networking_and_Information_Technology_Research_and_Development http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Common_Criteria http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Ramanathan_V._Guha http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Semantic_web http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_Web
# http://dbpedia.org/resource/James_Hendler http://dbpedia.org/ontology/field http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Kristinn_R._Thórisson http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Web_scraping http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Free_Software_Directory http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Topic_Maps http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Rights_Expression_Language http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Concept_map http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/SWI-Prolog http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Philosophy_of_information http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Frank_van_Harmelen http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/David_S._Frankel http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Tim_Finin http://dbpedia.org/ontology/field http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Semantic_web http://dbpedia.org/ontology/wikiPageRevisionID 177677665
# http://dbpedia.org/resource/Metaweb_(disambiguation) http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Smart_city http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/AI_winter http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Ashok_Agrawala http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Algolia http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Microdata_(HTML) http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Ambient_intelligence http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Metacrap http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Drew_McDermott http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Gellish http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/FOAF_(ontology) http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Knowledge_representation_and_reasoning http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/Description_logic http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web
# http://dbpedia.org/resource/MediaWiki http://dbpedia.org/ontology/wikiPageWikiLink http://dbpedia.org/resource/Semantic_web

# %%
dbpedia_sparql.sparql.setQuery(dbpedia_sparql.gen_query("DESCRIBE :Semantic_web"))
res = dbpedia_sparql.sparql.query().convert()
# Out:
# /usr/local/lib/python3.7/dist-packages/SPARQLWrapper/Wrapper.py:979: RuntimeWarning: Sending Accept header '*/*' because unexpected returned format 'json' in a 'DESCRIBE' SPARQL query form
#   warnings.warn("Sending Accept header '*/*' because unexpected returned format '%s' in a '%s' SPARQL query form" % (self.returnFormat, self.queryType), RuntimeWarning)

# %%
res["results"]
# Out:
# {'distinct': False,
#  'ordered': True,
#  'bindings': [{'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_spectrum'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/List_of_University_of_Maryland,_Baltimore_County_people'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/A.nnotate'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Data_Reference_Model'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Formal_concept_analysis'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Terminology_extraction'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Peter_Fox_(professor)'},
#    'p': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/field'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Qitera'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/HTML'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Multi-user_MIMO'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Knowledge-based_systems'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Vasant_Honavar'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/HTML_email'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Plant_ontology'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/VOA3R'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Knowledge_Engineering_and_Machine_Learning_Group'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/GNOWSYS'},
#    'p': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/genre'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Translatewiki.net'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Dieter_Fensel'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/SPARQL'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Universal_Data_Element_Framework'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Social_web'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Donna_Carol_Kurtz'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Compat.egov'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_warehousing'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://en.wikipedia.org/wiki/Semantic_web'},
#    'p': {'type': 'uri', 'value': 'http://xmlns.com/foaf/0.1/primaryTopic'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_technology'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/GNOWSYS'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Prolog'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Pat_Hayes'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Peter_Fox_(professor)'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Regator'},
#    'p': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/type'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Metadata_publishing'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/International_World_Wide_Web_Conference'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Calais_(Reuters_product)'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Wright_State_University'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Tag_(metadata)'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Logic_in_computer_science'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Exhibit_(web_editing_tool)'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Tool_for_Ontology_Development_and_Editing_(TODE)'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Sesame_(framework)'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Freebase'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Deborah_McGuinness'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/DOAP'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Provenance'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/RuleML_Symposium'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Integrated_Authority_File'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/State_(website)'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Katia_Sycara'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/OMDoc'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Collaborative_network'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/IPlant_Collaborative'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/ChemSpider'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Wired_for_Thought'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Celtrak'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Simple_HTML_Ontology_Extensions'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_publishing'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Vrije_Universiteit_Amsterdam'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/James_Hendler'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'},
#    'p': {'type': 'uri', 'value': 'http://xmlns.com/foaf/0.1/isPrimaryTopicOf'},
#    'o': {'type': 'uri', 'value': 'http://en.wikipedia.org/wiki/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/CycL'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Intelligence_analysis'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Internet_of_things'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/HTTPRange-14'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Knowledge-based_engineering'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Image_retrieval'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_service-oriented_architecture'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Web_content_lifecycle'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/World_Brain'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'},
#    'p': {'type': 'uri', 'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#    'o': {'type': 'literal', 'value': 'Semantic web', 'lang': 'en'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Nigel_Shadbolt'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Information_extraction'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Dean_Allemang'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_query'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Service_discovery'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Regator'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Bio2RDF'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Journal_of_Web_Semantics'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Shelley_Powers'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Data_mapping'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Pedagogy_3.0'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Distinguo'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Gandalf_(theorem_prover)'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Metaclass_(disambiguation)'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Alan_Rector'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Annotation'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/E-democracy'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Reasoning_system'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageRedirects'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_Web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Hipertext.net'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_MediaWiki'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Wendy_Hall'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Intraweb'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Tuple'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Metadata_discovery'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Computer-supported_collaboration'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Text_mining'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Sensor_Web'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Inference'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/David_De_Roure'},
#    'p': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/field'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Cwm_(software)'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Web_intelligence'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Rule_Interchange_Format'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'},
#    'p': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/wikiPageID'},
#    'o': {'type': 'literal',
#     'value': 52314,
#     'datatype': 'http://www.w3.org/2001/XMLSchema#integer'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Mathematical_knowledge_management'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Datalog'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Tim_Finin'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Applied_ontology'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'},
#    'p': {'type': 'uri', 'value': 'http://www.w3.org/ns/prov#wasDerivedFrom'},
#    'o': {'type': 'uri',
#     'value': 'http://en.wikipedia.org/wiki/Semantic_web?oldid=177677665'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/HTML5'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/VideoLectures.net'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/David_De_Roure'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Information_science'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Web_annotation'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Trekiz'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Paulo_Pinheiro'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Intelligent_Web_Business_Laboratory'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Daylife'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Data_exchange'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Class_(computer_programming)'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Neuroinformatics'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_search'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Networking_and_Information_Technology_Research_and_Development'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Common_Criteria'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Ramanathan_V._Guha'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_Web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/James_Hendler'},
#    'p': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/field'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Kristinn_R._Thórisson'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Web_scraping'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Free_Software_Directory'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Topic_Maps'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Rights_Expression_Language'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Concept_map'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/SWI-Prolog'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Philosophy_of_information'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Frank_van_Harmelen'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/David_S._Frankel'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Tim_Finin'},
#    'p': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/field'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageRevisionID'},
#    'o': {'type': 'literal',
#     'value': 177677665,
#     'datatype': 'http://www.w3.org/2001/XMLSchema#integer'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Metaweb_(disambiguation)'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Smart_city'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/AI_winter'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Ashok_Agrawala'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Algolia'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Microdata_(HTML)'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Ambient_intelligence'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Metacrap'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Drew_McDermott'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Gellish'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/FOAF_(ontology)'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Knowledge_representation_and_reasoning'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Description_logic'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}},
#   {'s': {'type': 'uri', 'value': 'http://dbpedia.org/resource/MediaWiki'},
#    'p': {'type': 'uri',
#     'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#    'o': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_web'}}]}

# %%
def find_redirects(entity_df: dict):
    pages = []
    for key, predicates in entity_df.items():
        for predicate, value in predicates.items():
            if predicate == "http://dbpedia.org/ontology/wikiPageRedirects" :
                pages.append(key)
    return pages

def strip_prefix(prefix: str, payload) -> str:
    if payload.startswith(prefix):
        return payload[len(prefix):]
    return payload

def add_wikipedia_prefix(prefix, name):
    return "http://en.wikipedia.org/wiki/" + name

def add_dbpedia_prefix(prefix, name):
    return "http://dbpedia.org/resource/" + name

"""
def fetch_redirects(entity_name: str, entity_df : dict):
    full_entity_name = get_dbpedia_link(entity_name)
    to_crawl = [strip_prefix("http://dbpedia.org/resource/", resource) for resource in find_redirects(entity_df)]
    
    entity_df_cloned = entity_df.copy()
    
    owl_sameas = "http://www.w3.org/2002/07/owl#sameAs"
    
    for redirected in to_crawl:
        redirected_df = fetch_dataset(redirected, provider="dbpedia")
        if redirected in redirected_df:
            to_copy = [key for key in list(redirected.keys()) \ 
                         if key not in [add_dbpedia_prefix(redirected), \
                                        add_wikipedia_prefix(redirected)] ]
            
            for k in to_copy:
                entity_df_cloned[full_entity_name][to_copy]
    
    
    return entity_df_cloned

"""

# res = fetch_redirects("Semantic_Web", semweb_df)
# Out:
# ['Criticism_of_the_Semantic_Web', 'Semantic_Internet', 'Web_3.0', 'Semantic_web', 'Syntactic_Web', 'SemWeb', 'Semantic_internet', 'Semantic_integrity', 'The_semantic_web', 'Web_3', 'Semantic-web', 'Semweb']
# Dataset Criticism_of_the_Semantic_Web.json already available. Downloading from https://dbpedia.org/data/Criticism_of_the_Semantic_Web.json
# Done
# Dataset Semantic_Internet.json already available. Downloading from https://dbpedia.org/data/Semantic_Internet.json
# Done
# Dataset Web_3.0.json already available. Downloading from https://dbpedia.org/data/Web_3.0.json
# Done
# Dataset Semantic_web.json already available. Downloading from https://dbpedia.org/data/Semantic_web.json
# Done
# Dataset Syntactic_Web.json already available. Downloading from https://dbpedia.org/data/Syntactic_Web.json
# Done
# Dataset SemWeb.json already available. Downloading from https://dbpedia.org/data/SemWeb.json
# Done
# Dataset Semantic_internet.json already available. Downloading from https://dbpedia.org/data/Semantic_internet.json
# Done
# Dataset Semantic_integrity.json already available. Downloading from https://dbpedia.org/data/Semantic_integrity.json
# Done
# Dataset The_semantic_web.json already available. Downloading from https://dbpedia.org/data/The_semantic_web.json
# Done
# Dataset Web_3.json already available. Downloading from https://dbpedia.org/data/Web_3.json
# Done
# Dataset Semantic-web.json already available. Downloading from https://dbpedia.org/data/Semantic-web.json
# Done
# Dataset Semweb.json already available. Downloading from https://dbpedia.org/data/Semweb.json
# Done

# %%
# Out:
# {'http://dbpedia.org/resource/Criticism_of_the_Semantic_Web': {'http://dbpedia.org/ontology/wikiPageRedirects': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Semantic_Internet': {'http://dbpedia.org/ontology/wikiPageRedirects': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Web_3.0': {'http://dbpedia.org/ontology/wikiPageRedirects': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Carole_Goble': {'http://dbpedia.org/ontology/field': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Wendy_Hall': {'http://dbpedia.org/ontology/field': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Semantic_web': {'http://dbpedia.org/ontology/wikiPageRedirects': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Syntactic_Web': {'http://dbpedia.org/ontology/wikiPageRedirects': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/SemWeb': {'http://dbpedia.org/ontology/wikiPageRedirects': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://en.wikipedia.org/wiki/Semantic_Web': {'http://xmlns.com/foaf/0.1/primaryTopic': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Marc_Twagirumukiza': {'http://dbpedia.org/ontology/field': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Nigel_Shadbolt': {'http://dbpedia.org/ontology/knownFor': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}],
#   'http://dbpedia.org/ontology/field': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Rudi_Studer': {'http://dbpedia.org/ontology/field': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/DBpedia': {'http://dbpedia.org/ontology/genre': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Open_Semantic_Framework': {'http://dbpedia.org/ontology/genre': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Ian_Horrocks': {'http://dbpedia.org/ontology/field': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/James_Hendler': {'http://dbpedia.org/ontology/knownFor': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/UMBEL': {'http://dbpedia.org/ontology/genre': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Semantic_Web': {'http://www.w3.org/1999/02/22-rdf-syntax-ns#type': [{'type': 'uri',
#     'value': 'http://dbpedia.org/class/yago/Communication100033020'},
#    {'type': 'uri', 'value': 'http://dbpedia.org/class/yago/Act100030358'},
#    {'type': 'uri', 'value': 'http://dbpedia.org/class/yago/Activity100407535'},
#    {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#Thing'},
#    {'type': 'uri', 'value': 'http://dbpedia.org/class/yago/Event100029378'},
#    {'type': 'uri', 'value': 'http://dbpedia.org/class/yago/Service100577525'},
#    {'type': 'uri', 'value': 'http://dbpedia.org/class/yago/Age104924103'},
#    {'type': 'uri', 'value': 'http://dbpedia.org/class/yago/Buzzword106608277'},
#    {'type': 'uri', 'value': 'http://dbpedia.org/class/yago/Work100575741'},
#    {'type': 'uri',
#     'value': 'http://dbpedia.org/class/yago/WikicatInternetAges'},
#    {'type': 'uri', 'value': 'http://dbpedia.org/class/yago/Nonsense106607339'},
#    {'type': 'uri', 'value': 'http://dbpedia.org/class/yago/WikicatBuzzwords'},
#    {'type': 'uri', 'value': 'http://dbpedia.org/class/yago/Property104916342'},
#    {'type': 'uri',
#     'value': 'http://dbpedia.org/class/yago/YagoPermanentlyLocatedEntity'},
#    {'type': 'uri',
#     'value': 'http://dbpedia.org/class/yago/Attribute100024264'},
#    {'type': 'uri',
#     'value': 'http://dbpedia.org/class/yago/Abstraction100002137'},
#    {'type': 'uri',
#     'value': 'http://dbpedia.org/class/yago/PsychologicalFeature100023100'},
#    {'type': 'uri', 'value': 'http://dbpedia.org/class/yago/Message106598915'},
#    {'type': 'uri', 'value': 'http://dbpedia.org/ontology/Software'},
#    {'type': 'uri',
#     'value': 'http://dbpedia.org/class/yago/WikicatWebServices'}],
#   'http://www.w3.org/2000/01/rdf-schema#label': [{'type': 'literal',
#     'value': 'セマンティック・ウェブ',
#     'lang': 'ja'},
#    {'type': 'literal', 'value': 'Semantic Web', 'lang': 'pl'},
#    {'type': 'literal', 'value': 'ويب دلالي', 'lang': 'ar'},
#    {'type': 'literal', 'value': 'Web semântica', 'lang': 'pt'},
#    {'type': 'literal', 'value': 'Semantic Web', 'lang': 'en'},
#    {'type': 'literal', 'value': '语义网', 'lang': 'zh'},
#    {'type': 'literal', 'value': 'Semantisch web', 'lang': 'nl'},
#    {'type': 'literal', 'value': 'Семантическая паутина', 'lang': 'ru'},
#    {'type': 'literal', 'value': 'Web semantico', 'lang': 'it'},
#    {'type': 'literal', 'value': 'Web semántica', 'lang': 'es'},
#    {'type': 'literal', 'value': 'Semantic Web', 'lang': 'de'},
#    {'type': 'literal', 'value': 'Web sémantique', 'lang': 'fr'}],
#   'http://www.w3.org/2000/01/rdf-schema#comment': [{'type': 'literal',
#     'value': "Het semantisch web verschaft een standaardframework waarmee data gedeeld en hergebruikt kunnen worden. Het is een samenwerking onder leiding van het internationale orgaan voor internetstandaarden, het World Wide Web Consortium (W3C). Het semantisch web is geen synoniem voor Web 2.0, zoals soms wel wordt verondersteld. Tim Berners-Lee beschreef het semantische web als een component van 'Web 3.0'. Soms wordt het gebruikt als synoniem voor Web 3.0, hoewel de definities verschillen.",
#     'lang': 'nl'},
#    {'type': 'literal',
#     'value': 'Semantic Web (sieci semantyczne) – projekt, który ma przyczynić się do utworzenia i rozpowszechnienia standardów opisywania treści w Internecie w sposób, który umożliwi maszynom i programom (np. tzw. agentom) przetwarzanie informacji w sposób odpowiedni do ich znaczenia. Wśród standardów sieci semantycznych znajdują się m.in. OWL, RDF, RDF Schema (inaczej RDFS). Znaczenia zasobów informacyjnych określa się za pomocą tzw. ontologii.',
#     'lang': 'pl'},
#    {'type': 'literal',
#     'value': "Le Web sémantique, ou toile sémantique, est une extension du Web standardisée par le World Wide Web Consortium (W3C). Ces standards encouragent l'utilisation de formats de données et de protocoles d'échange normés sur le Web, avec comme format de base le Resource Description Framework (RDF).",
#     'lang': 'fr'},
#    {'type': 'literal',
#     'value': 'セマンティック・ウェブ（英: semantic web）は W3C のティム・バーナーズ＝リーによって提唱された、ウェブページの意味を扱うことを可能とする標準やツール群の開発によってワールド・ワイド・ウェブの利便性を向上させるプロジェクト。セマンティック・ウェブの目的はウェブページの閲覧という行為に、データの交換の側面に加えて意味の疎通を付け加えることにある。 現在のワールド・ワイド・ウェブ上のコンテンツは主にHTMLで記述されている。HTMLでは文書構造を伝えることは可能だが、個々の単語の意味をはじめとする詳細な意味を伝えることはできない。これに対し、セマンティック・ウェブはXMLによって記述した文書にRDFやOWLを用いてタグを付け加える。この、データの意味を記述したタグが文書の含む意味を形式化し、コンピュータによる自動的な情報の収集や分析へのアプローチが可能となると期待されている。オントロジーを扱う階層まではW3Cにより標準化されているが、それ以上の階層の開発は難しいため、実現と標準化には長期間掛かると予想されている。また、既存のWebサイトに対するメタデータ付与の作業が必要であるため、Web全域への普及に関しても長期間掛かると予想されている。',
#     'lang': 'ja'},
#    {'type': 'literal',
#     'value': 'Семанти́ческая паути́на (англ. semantic web) — это общедоступная глобальная семантическая сеть, формируемая на базе Всемирной паутины путём стандартизации представления информации в виде, пригодном для машинной обработки.',
#     'lang': 'ru'},
#    {'type': 'literal',
#     'value': 'La web semántica (del inglés semantic web) es un conjunto de actividades desarrolladas en el seno de World Wide Web Consortium con tendencia a la creación de tecnologías para publicar datos legibles por aplicaciones informáticas (máquinas en la terminología de la Web semántica). Se basa en la idea de añadir metadatos semánticos y ontológicos a la World Wide Web. Esas informaciones adicionales —que describen el contenido, el significado y la relación de los datos— se deben proporcionar de manera formal, para que así sea posible evaluarlas automáticamente por máquinas de procesamiento. El objetivo es mejorar Internet ampliando la interoperabilidad entre los sistemas informáticos usando "agentes inteligentes". Agentes inteligentes son programas en las computadoras que buscan información sin o',
#     'lang': 'es'},
#    {'type': 'literal',
#     'value': 'The Semantic Web is an extension of the Web through standards by the World Wide Web Consortium (W3C). The standards promote common data formats and exchange protocols on the Web, most fundamentally the Resource Description Framework (RDF). The 2001 Scientific American article by Berners-Lee, Hendler, and Lassila described an expected evolution of the existing Web to a Semantic Web. In 2006, Berners-Lee and colleagues stated that: "This simple idea…remains largely unrealized".In 2013, more than four million Web domains contained Semantic Web markup.',
#     'lang': 'en'},
#    {'type': 'literal',
#     'value': 'إن ورود المعلومات على الإنترنت يزداد بشكل كبير، فقد أصبح الإنترنت مكانًا للتعبير عن الأفكار، سرد القصص، إنشاء المدونات ومشاركة الفيديوهات والصور والملفات الصوتية وما إلى ذلك. وهو ما جعل كمّ المعلومات المتوفرة للفرد الواحد أكبر بكثير ممايُمكن له أن يستفيد منه. تعريض العقل البشري لهذا الكم الهائل من المعلومات من شأنه أن يتسبب فيما يُمكن أن نصفه بوصف "الضياع في فضاء المعلومات"، وذلك راجع إلى بقاء المعلومات المفيدة بعيدة المنال بسبب تراكم الكثير من المعلومات غير المفيدة وغير المرتبطة بالموضوع المراد البحث عنه من قبل المستخدم.لحسن الحظ، مثلما يزداد ورود المعلومات، تزداد مقدرات معالجة المعلومات اوتوماتيكياً، لذا يوجد إمكانيات كبيرة للاستفادة من مقدرات الأتمتة هذه بهدف استخراج المعلومات والخدمات من فيضان الويب والمرتبطة بالمستخدم، وتوصيلها إليه عن طريق واجهة مستخدم معيارية (Standardized User Inte',
#     'lang': 'ar'},
#    {'type': 'literal',
#     'value': 'A Web semântica é uma extensão da World Wide Web atual, que permitirá aos computadores e humanos trabalharem em cooperação. A Web semântica interliga significados de palavras e, neste âmbito, tem como finalidade conseguir atribuir um significado (sentido) aos conteúdos publicados na Internet de modo que seja perceptível tanto pelo humano como pelo computador. A ideia da Web Semântica surgiu em 2001, quando Tim Berners-Lee, James Hendler e Ora Lassila publicaram um artigo na revista Scientific American, intitulado: “Web Semântica: um novo formato de conteúdo para a Web que tem significado para computadores vai iniciar uma revolução de novas possibilidades.”',
#     'lang': 'pt'},
#    {'type': 'literal',
#     'value': "Con il termine web semantico, termine coniato dal suo ideatore, Tim Berners-Lee, si intende la trasformazione del World Wide Web in un ambiente dove i documenti pubblicati (pagine HTML, file, immagini, e così via) sono associati ad informazioni e dati (metadati) che ne specificano il contesto semantico in un formato adatto all'interrogazione e l'interpretazione (es. tramite motori di ricerca) e, più in generale, all'elaborazione automatica.",
#     'lang': 'it'},
#    {'type': 'literal',
#     'value': '语义网（Semantic Web）是由万维网联盟的蒂姆·伯纳斯-李（Tim Berners-Lee）在1998年提出的一个概念，它的核心是：通过给万维网上的文档（如: HTML）添加能够被计算机所理解的语义（Meta data），从而使整个互联网成为一个通用的信息交换媒介。语义万维网通过使用标准、置标语言和相关的处理工具来扩展万维网的能力。不过语意网概念实际上是基于很多已有技术的，也依赖于后来和text-and-markup与知识表现的综合。那些渊源甚至可以追溯到20世纪60年代末期的Allan M. Collins、M. Ross Quillian、Elizabeth F. Loftus等人的研究，还有之后70年代初R.F.Simon、R.C.Schamk、Minsky等人陆续提出的一些理论上的成果，其中Simon在进行自然语言理解的应用研究时提出了语义网络Semantic Network（不是现在的Semantic Web）的概念。当时人们甚至发明了以逻辑为基础的程序设计语言Prolog。 "语义"网是由比现今成熟的网际搜索工具更加行之有效的、更加广泛意义的并且自动聚集和搜集信息的文档组成的。其最基本的元素就是语义链接。 通过下列方法可以提升全球資訊網以及其互连的资源的易用性（usability）和實用性（usefulness）：',
#     'lang': 'zh'},
#    {'type': 'literal',
#     'value': 'Das Semantic Web erweitert das Web, um Daten zwischen Rechnern einfacher austauschbar und für sie einfacher verwertbar zu machen; so kann beispielsweise der Begriff „Bremen“ in einem Webdokument um die Information ergänzt werden, ob hier ein Schiffs-, Familien- oder der Stadtname gemeint ist. Diese zusätzlichen Informationen explizieren die sonst nur unstrukturiert vorkommenden Daten. Zur Realisierung dienen Standards zur Veröffentlichung und Nutzung maschinenlesbarer Daten (insbesondere RDF).',
#     'lang': 'de'}],
#   'http://www.w3.org/2002/07/owl#sameAs': [{'type': 'uri',
#     'value': 'http://wikidata.dbpedia.org/resource/Q54837'},
#    {'type': 'uri', 'value': 'http://it.dbpedia.org/resource/Web_semantico'},
#    {'type': 'uri', 'value': 'http://de.dbpedia.org/resource/Semantic_Web'},
#    {'type': 'uri', 'value': 'http://rdf.freebase.com/ns/m.0bbv9w2'},
#    {'type': 'uri', 'value': 'http://d-nb.info/gnd/4688372-1'},
#    {'type': 'uri', 'value': 'http://pl.dbpedia.org/resource/Semantic_Web'},
#    {'type': 'uri', 'value': 'http://pt.dbpedia.org/resource/Web_semântica'},
#    {'type': 'uri',
#     'value': 'http://el.dbpedia.org/resource/Σημασιολογικός_Ιστός'},
#    {'type': 'uri', 'value': 'http://ja.dbpedia.org/resource/セマンティック・ウェブ'},
#    {'type': 'uri', 'value': 'http://eu.dbpedia.org/resource/Web_semantiko'},
#    {'type': 'uri', 'value': 'http://cs.dbpedia.org/resource/Sémantický_web'},
#    {'type': 'uri', 'value': 'http://id.dbpedia.org/resource/Web_semantik'},
#    {'type': 'uri', 'value': 'http://ko.dbpedia.org/resource/시맨틱_웹'},
#    {'type': 'uri', 'value': 'http://yago-knowledge.org/resource/Semantic_Web'},
#    {'type': 'uri', 'value': 'http://rdf.freebase.com/ns/m.076k0'},
#    {'type': 'uri', 'value': 'http://es.dbpedia.org/resource/Web_semántica'},
#    {'type': 'uri', 'value': 'http://fr.dbpedia.org/resource/Web_sémantique'},
#    {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q54837'},
#    {'type': 'uri', 'value': 'http://nl.dbpedia.org/resource/Semantisch_web'},
#    {'type': 'uri', 'value': 'http://dbpedia.org/resource/Semantic_Web'}],
#   'http://purl.org/dc/terms/subject': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Category:Internet_ages'},
#    {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Category:Knowledge_engineering'},
#    {'type': 'uri', 'value': 'http://dbpedia.org/resource/Category:Buzzwords'},
#    {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Category:Emerging_technologies'},
#    {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Category:Web_services'},
#    {'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Category:Semantic_Web'}],
#   'http://xmlns.com/foaf/0.1/homepage': [{'type': 'uri',
#     'value': 'http://www.w3.org/standards/semanticweb/'}],
#   'http://xmlns.com/foaf/0.1/depiction': [{'type': 'uri',
#     'value': 'http://commons.wikimedia.org/wiki/Special:FilePath/RDF_example.svg'}],
#   'http://xmlns.com/foaf/0.1/isPrimaryTopicOf': [{'type': 'uri',
#     'value': 'http://en.wikipedia.org/wiki/Semantic_Web'}],
#   'http://dbpedia.org/property/n': [{'type': 'literal',
#     'value': 'no',
#     'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString'}],
#   'http://www.w3.org/ns/prov#wasDerivedFrom': [{'type': 'uri',
#     'value': 'http://en.wikipedia.org/wiki/Semantic_Web?oldid=741952532'}],
#   'http://dbpedia.org/ontology/wikiPageExternalLink': [{'type': 'uri',
#     'value': 'http://www.amazon.com/gp/product/0470396792'},
#    {'type': 'uri',
#     'value': 'http://www.w3.org/2005/Incubator/urw3/XGR-urw3-20080331/'},
#    {'type': 'uri', 'value': 'http://esw.w3.org/topic/ConverterToRdf'},
#    {'type': 'uri', 'value': 'http://www-sop.inria.fr/acacia/soft/corese/'},
#    {'type': 'uri',
#     'value': 'http://www.springer.com/computer/database+management+%26+information+retrieval/book/978-3-662-43795-7'},
#    {'type': 'uri', 'value': 'http://www.semantic-web-book.org'},
#    {'type': 'uri', 'value': 'http://www.w3.org/standards/semanticweb/'}],
#   'http://dbpedia.org/property/commons': [{'type': 'literal',
#     'value': 'Category:Semantic Web',
#     'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString'}],
#   'http://dbpedia.org/property/q': [{'type': 'literal',
#     'value': 'no',
#     'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString'}],
#   'http://dbpedia.org/property/s': [{'type': 'literal',
#     'value': 'no',
#     'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString'}],
#   'http://dbpedia.org/property/d': [{'type': 'literal',
#     'value': 'Q54837',
#     'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString'}],
#   'http://dbpedia.org/ontology/abstract': [{'type': 'literal',
#     'value': "Het semantisch web verschaft een standaardframework waarmee data gedeeld en hergebruikt kunnen worden. Het is een samenwerking onder leiding van het internationale orgaan voor internetstandaarden, het World Wide Web Consortium (W3C). Het semantisch web is geen synoniem voor Web 2.0, zoals soms wel wordt verondersteld. Tim Berners-Lee beschreef het semantische web als een component van 'Web 3.0'. Soms wordt het gebruikt als synoniem voor Web 3.0, hoewel de definities verschillen.",
#     'lang': 'nl'},
#    {'type': 'literal',
#     'value': '语义网（Semantic Web）是由万维网联盟的蒂姆·伯纳斯-李（Tim Berners-Lee）在1998年提出的一个概念，它的核心是：通过给万维网上的文档（如: HTML）添加能够被计算机所理解的语义（Meta data），从而使整个互联网成为一个通用的信息交换媒介。语义万维网通过使用标准、置标语言和相关的处理工具来扩展万维网的能力。不过语意网概念实际上是基于很多已有技术的，也依赖于后来和text-and-markup与知识表现的综合。那些渊源甚至可以追溯到20世纪60年代末期的Allan M. Collins、M. Ross Quillian、Elizabeth F. Loftus等人的研究，还有之后70年代初R.F.Simon、R.C.Schamk、Minsky等人陆续提出的一些理论上的成果，其中Simon在进行自然语言理解的应用研究时提出了语义网络Semantic Network（不是现在的Semantic Web）的概念。当时人们甚至发明了以逻辑为基础的程序设计语言Prolog。 "语义"网是由比现今成熟的网际搜索工具更加行之有效的、更加广泛意义的并且自动聚集和搜集信息的文档组成的。其最基本的元素就是语义链接。 通过下列方法可以提升全球資訊網以及其互连的资源的易用性（usability）和實用性（usefulness）： \n* "标记"了语义信息的文档。这可以是机器可以理解的关于文档内容（例如文档的作者,标题,简介等)的描述,或者是描述该网站所拥有的服务和资源.(注意:任何东西都是能被URI-统一资源定位符-所描述的,因此语义网能理解人物、地方、想法、類別等等) \n* 通用元数据詞滙表(本体论)及詞滙間的影射使得文檔作者知道如何來標記文檔方可讓機器識別他想提供的元數據. \n* 利用元数据为语义网用户执行任务的自动软件代理(agent). \n* 為自動軟件代理提供特定信息的網絡服务 (例如,可信度服務可以讓軟件代理查詢某個在线商店是否曾經有過不良紀錄或者發送過垃圾郵件).',
#     'lang': 'zh'},
#    {'type': 'literal',
#     'value': "Con il termine web semantico, termine coniato dal suo ideatore, Tim Berners-Lee, si intende la trasformazione del World Wide Web in un ambiente dove i documenti pubblicati (pagine HTML, file, immagini, e così via) sono associati ad informazioni e dati (metadati) che ne specificano il contesto semantico in un formato adatto all'interrogazione e l'interpretazione (es. tramite motori di ricerca) e, più in generale, all'elaborazione automatica. Con l'interpretazione del contenuto dei documenti che il Web semantico impone, saranno possibili ricerche molto più evolute delle attuali, basate sulla presenza nel documento di parole chiave, e altre operazioni specialistiche come la costruzione di reti di relazioni e connessioni tra documenti secondo logiche più elaborate del semplice collegamento ipertestuale.",
#     'lang': 'it'},
#    {'type': 'literal',
#     'value': 'La web semántica (del inglés semantic web) es un conjunto de actividades desarrolladas en el seno de World Wide Web Consortium con tendencia a la creación de tecnologías para publicar datos legibles por aplicaciones informáticas (máquinas en la terminología de la Web semántica). Se basa en la idea de añadir metadatos semánticos y ontológicos a la World Wide Web. Esas informaciones adicionales —que describen el contenido, el significado y la relación de los datos— se deben proporcionar de manera formal, para que así sea posible evaluarlas automáticamente por máquinas de procesamiento. El objetivo es mejorar Internet ampliando la interoperabilidad entre los sistemas informáticos usando "agentes inteligentes". Agentes inteligentes son programas en las computadoras que buscan información sin operadores humanos. El precursor de la idea, Tim Berners-Lee, intentó desde el principio incluir información semántica en su creación, la World Wide Web, pero por diferentes causas no fue posible. Por ese motivo introdujo el concepto de semántica con la intención de recuperar dicha omisión.',
#     'lang': 'es'},
#    {'type': 'literal',
#     'value': 'A Web semântica é uma extensão da World Wide Web atual, que permitirá aos computadores e humanos trabalharem em cooperação. A Web semântica interliga significados de palavras e, neste âmbito, tem como finalidade conseguir atribuir um significado (sentido) aos conteúdos publicados na Internet de modo que seja perceptível tanto pelo humano como pelo computador. A ideia da Web Semântica surgiu em 2001, quando Tim Berners-Lee, James Hendler e Ora Lassila publicaram um artigo na revista Scientific American, intitulado: “Web Semântica: um novo formato de conteúdo para a Web que tem significado para computadores vai iniciar uma revolução de novas possibilidades.” A web semântica é a relação de interatividade do homem e o computador, onde um depende do outro para a conclusão de tarefas, assim acepção de entendimento do comando estipulado do ser humano à interface operacional da maquina dando um significado de ordem a ser executada. Sendo desta forma uma espécie de escrita de entendimento tanto para o computador e para usuário, por meio de organização das informações contida na máquina, através do seu perfil de suas últimas pesquisas realizadas, originando um repositório de dados lincados, como se fosse um verbete de enciclopédia. Podemos fazer uma assimilação da web semântica com a Ciência da Informação, pelo fato de possuir a ideia estrutural de arranjo sistêmico, agrupando um conjunto de coleta de análise, classificação, armazenamento, disseminação e recuperação de informação como se fosse uma enciclopédia. O objetivo principal da web semântica não é, pelo menos para já, treinar as máquinas para que se comportem como pessoas, mas sim desenvolver tecnologias e linguagens que tornem a informação legível para as máquinas. A finalidade passa pelo desenvolvimento de um modelo tecnológico que permita a partilha global de conhecimento assistido por máquinas (W3C 2001). A integração das linguagens ou tecnologias eXtensible Markup Language (XML), Resource Description Framework (RDF), arquiteturas de metadados, ontologias, agentes computacionais, entre outras, favorecerá o aparecimento de serviços Web que garantam a interoperabilidade e cooperação. Ultimamente tem-se associado a Web Semântica à Web 3.0, como um próximo movimento da internet depois da Web 2.0 que já inicia seu crescimento.',
#     'lang': 'pt'},
#    {'type': 'literal',
#     'value': "Le Web sémantique, ou toile sémantique, est une extension du Web standardisée par le World Wide Web Consortium (W3C). Ces standards encouragent l'utilisation de formats de données et de protocoles d'échange normés sur le Web, avec comme format de base le Resource Description Framework (RDF). Selon le W3C, « le Web sémantique fournit un modèle qui permet aux données d'être partagées et réutilisées entre plusieurs applications, entreprises et groupes d'utilisateurs ». L'expression a été inventée par Tim Berners-Lee (inventeur du Web et directeur du W3C), qui supervise le développement des technologies communes du Web sémantique. Il le définit comme « une toile de données qui peuvent être traitées directement et indirectement par des machines pour aider leurs utilisateurs à créer de nouvelles connaissances ». Pour y parvenir, le Web sémantique met en œuvre le Web des données qui consiste à lier et structurer l'information sur Internet pour accéder simplement à la connaissance qu'elle contient déjà. Alors que ses détracteurs ont mis en doute sa faisabilité, ses promoteurs font valoir que les applications réalisées par les chercheurs dans l'industrie, la biologie et les sciences humaines ont déjà prouvé la validité de ce nouveau concept. L'article original de Tim Berners-Lee en 2001 dans le Scientific American a décrit une évolution attendue du Web existant vers un Web sémantique, mais cela n'a pas encore eu lieu. En 2006, Tim Berners-Lee et ses collègues ont déclaré : « Cette idée simple… reste largement inexploitée. »",
#     'lang': 'fr'},
#    {'type': 'literal',
#     'value': 'The Semantic Web is an extension of the Web through standards by the World Wide Web Consortium (W3C). The standards promote common data formats and exchange protocols on the Web, most fundamentally the Resource Description Framework (RDF). According to the W3C, "The Semantic Web provides a common framework that allows data to be shared and reused across application, enterprise, and community boundaries". The term was coined by Tim Berners-Lee for a web of data that can be processed by machines.While its critics have questioned its feasibility, proponents argue that applications in industry, biology and human sciences research have already proven the validity of the original concept. The 2001 Scientific American article by Berners-Lee, Hendler, and Lassila described an expected evolution of the existing Web to a Semantic Web. In 2006, Berners-Lee and colleagues stated that: "This simple idea…remains largely unrealized".In 2013, more than four million Web domains contained Semantic Web markup.',
#     'lang': 'en'},
#    {'type': 'literal',
#     'value': 'セマンティック・ウェブ（英: semantic web）は W3C のティム・バーナーズ＝リーによって提唱された、ウェブページの意味を扱うことを可能とする標準やツール群の開発によってワールド・ワイド・ウェブの利便性を向上させるプロジェクト。セマンティック・ウェブの目的はウェブページの閲覧という行為に、データの交換の側面に加えて意味の疎通を付け加えることにある。 現在のワールド・ワイド・ウェブ上のコンテンツは主にHTMLで記述されている。HTMLでは文書構造を伝えることは可能だが、個々の単語の意味をはじめとする詳細な意味を伝えることはできない。これに対し、セマンティック・ウェブはXMLによって記述した文書にRDFやOWLを用いてタグを付け加える。この、データの意味を記述したタグが文書の含む意味を形式化し、コンピュータによる自動的な情報の収集や分析へのアプローチが可能となると期待されている。オントロジーを扱う階層まではW3Cにより標準化されているが、それ以上の階層の開発は難しいため、実現と標準化には長期間掛かると予想されている。また、既存のWebサイトに対するメタデータ付与の作業が必要であるため、Web全域への普及に関しても長期間掛かると予想されている。 セマンティックウェブはXML、XML Schema、RDF、RDF Schema、OWLなどの標準およびツール群から構成されている。「OWL ウェブ・オントロジー言語概要」はセマンティックウェブにおけるこれら標準およびツール群の機能・関連について述べている。',
#     'lang': 'ja'},
#    {'type': 'literal',
#     'value': 'Semantic Web (sieci semantyczne) – projekt, który ma przyczynić się do utworzenia i rozpowszechnienia standardów opisywania treści w Internecie w sposób, który umożliwi maszynom i programom (np. tzw. agentom) przetwarzanie informacji w sposób odpowiedni do ich znaczenia. Wśród standardów sieci semantycznych znajdują się m.in. OWL, RDF, RDF Schema (inaczej RDFS). Znaczenia zasobów informacyjnych określa się za pomocą tzw. ontologii. Sieć semantyczna jest wizją Tima Bernersa-Lee (twórcy standardu WWW i pierwszej przeglądarki internetowej, a także przewodniczącego W3C). W swoich założeniach sieć semantyczna ma korzystać z istniejącego protokołu komunikacyjnego, na którym bazuje dzisiejszy Internet. Różnica miałaby polegać na tym, że przesyłane dane mogłyby być \'rozumiane\' także przez maszyny. Owo \'rozumienie\' polegałoby na tym, że dane przekazywane byłyby w postaci, w której można by powiązać ich znaczenia między sobą a także w ramach odpowiedniego kontekstu. Informacje przekazywane w ramach sieci semantycznej wymagałyby nie tylko samych danych, ale także informacji o tychże (tzw. meta-danych). To właśnie meta-dane zawierałyby sformułowania dotyczące relacji między danymi oraz prawa logiki, które można do nich zastosować. Dzięki temu można by: \n*  powiązać różne dane znajdujące się w Internecie w ramach wspólnych jednostek znaczeniowych (np. strony dotyczące filmów, dziedzin nauki, kuchni francuskiej, etc.) \n*  rozróżnić dane, które dla maszyn są w tej chwili nierozróżnialne ze względu na identyczny zapis tekstowy (np. zamek - urządzenie do zamykania drzwi; urządzenie do łączenia w ustalonym położeniu elementów ubrania; okazała budowla mieszkalno-obronna) \n*  przeprowadzać na tychże danych wnioskowania, tzn. otrzymywać informacje na ich temat, które nie są zawarte explicite (np. na podstawie danej "Ewa jest żoną Adama", możemy też dowiedzieć się, że Ewa jest kobietą, Adam mężczyzną, Adam jest mężem Ewy, żaden inny mężczyzna nie jest mężem Ewy, etc.)',
#     'lang': 'pl'},
#    {'type': 'literal',
#     'value': 'إن ورود المعلومات على الإنترنت يزداد بشكل كبير، فقد أصبح الإنترنت مكانًا للتعبير عن الأفكار، سرد القصص، إنشاء المدونات ومشاركة الفيديوهات والصور والملفات الصوتية وما إلى ذلك. وهو ما جعل كمّ المعلومات المتوفرة للفرد الواحد أكبر بكثير ممايُمكن له أن يستفيد منه. تعريض العقل البشري لهذا الكم الهائل من المعلومات من شأنه أن يتسبب فيما يُمكن أن نصفه بوصف "الضياع في فضاء المعلومات"، وذلك راجع إلى بقاء المعلومات المفيدة بعيدة المنال بسبب تراكم الكثير من المعلومات غير المفيدة وغير المرتبطة بالموضوع المراد البحث عنه من قبل المستخدم.لحسن الحظ، مثلما يزداد ورود المعلومات، تزداد مقدرات معالجة المعلومات اوتوماتيكياً، لذا يوجد إمكانيات كبيرة للاستفادة من مقدرات الأتمتة هذه بهدف استخراج المعلومات والخدمات من فيضان الويب والمرتبطة بالمستخدم، وتوصيلها إليه عن طريق واجهة مستخدم معيارية (Standardized User Interface). إن أهمية الحصول على المعلومات بهذه الطريقة التكيفية يزداد بازدياد كتلة المعلومات المتوفرة على الإنترنت. تعتبر شبكة الوب أغنى المصادر المعلوماتية بما تحويه من مستندات ومعلومات ومصادر منوعة يمكن الوصول إليها عن طريق محركات البحث التقليدية. غير أن تنظيم هذه المعلومات والمستندات بصورة تسهل عملية البحث فيها والوصول إليها، يعتبر أمراً غاية في الصعوبة. يضاف إلى ذلك، أنه في ظل التزايد المستمر في حجم المعلومات المنشورة في شبكة الويب أصبح من الصعوبة بمكان قيام محركات البحث بإيجاد المعلومات المناسبة. ومن هذه المشكلة ظهرت فكرة "الويب ذات الدلالات والمعاني اللفظية"، أو ما يطلق عليه بالإنجليزية مصطلح (Semantic Web)، والتي هي امتداد للويب الحالية ولكن تختلف عنها بأنها تتفهم مدلولات الألفاظ والمعاني البشرية.',
#     'lang': 'ar'},
#    {'type': 'literal',
#     'value': 'Das Semantic Web erweitert das Web, um Daten zwischen Rechnern einfacher austauschbar und für sie einfacher verwertbar zu machen; so kann beispielsweise der Begriff „Bremen“ in einem Webdokument um die Information ergänzt werden, ob hier ein Schiffs-, Familien- oder der Stadtname gemeint ist. Diese zusätzlichen Informationen explizieren die sonst nur unstrukturiert vorkommenden Daten. Zur Realisierung dienen Standards zur Veröffentlichung und Nutzung maschinenlesbarer Daten (insbesondere RDF). Während Menschen solche Informationen aus dem gegebenen Kontext schließen können (aus dem Gesamttext, über die Art der Publikation oder der Rubrik in selbiger, Bilder etc.) und derartige Verknüpfungen unbewusst aufbauen, muss Maschinen dieser Kontext erst beigebracht werden; hierzu werden die Inhalte mit weiterführenden Informationen verknüpft. Das Semantic Web beschreibt dazu konzeptionell einen „Giant Global Graph“ (engl. ‚gigantischer globaler Graph‘). Dabei werden sämtliche Sachen von Interesse identifiziert und mit einer eindeutigen Adresse versehen als Knoten angelegt, die wiederum durch Kanten (ebenfalls jeweils eindeutig benannt) miteinander verbunden sind. Einzelne Dokumente im Web beschreiben dann eine Reihe von Kanten, und die Gesamtheit all dieser Kanten entspricht dem globalen Graphen.',
#     'lang': 'de'},
#    {'type': 'literal',
#     'value': 'Семанти́ческая паути́на (англ. semantic web) — это общедоступная глобальная семантическая сеть, формируемая на базе Всемирной паутины путём стандартизации представления информации в виде, пригодном для машинной обработки. В обычной Всемирной паутине, основанной на HTML-страницах, информация заложена в тексте страниц и предназначена для чтения и понимания человеком. Семантическая паутина состоит из машинно-читаемых элементов — узлов семантической сети, с опорой на онтологии. Благодаря этому программы-клиенты получают возможность непосредственно получать из интернета утверждения вида «предмет — вид взаимосвязи — другой предмет» и вычислять по ним логические заключения. Семантическая паутина работает параллельно с обычной Всемирной паутиной и на её основе, используя протокол HTTP и идентификаторы ресурсов URI. Название «Семантическая паутина» было впервые введено сэром Тимом Бернерсом-Ли (изобретателем Всемирной паутины) в сентябре 1998 года, и называется им «следующим шагом в развитии Всемирной паутины». Позже в своём блоге он предложил в качестве синонима термин «гигантский глобальный граф» (англ. giant global graph, GGG, по аналогии с WWW). Концепция семантической паутины была принята и продвигается консорциумом Всемирной паутины.',
#     'lang': 'ru'}],
#   'http://dbpedia.org/ontology/thumbnail': [{'type': 'uri',
#     'value': 'http://commons.wikimedia.org/wiki/Special:FilePath/RDF_example.svg?width=300'}],
#   'http://dbpedia.org/ontology/wikiPageRevisionID': [{'type': 'literal',
#     'value': 741952532,
#     'datatype': 'http://www.w3.org/2001/XMLSchema#integer'}],
#   'http://dbpedia.org/ontology/wikiPageID': [{'type': 'literal',
#     'value': 29123,
#     'datatype': 'http://www.w3.org/2001/XMLSchema#integer'}],
#   'http://dbpedia.org/property/wikt': [{'type': 'literal',
#     'value': 'no',
#     'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString'}],
#   'http://dbpedia.org/property/b': [{'type': 'literal',
#     'value': 'no',
#     'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString'}],
#   'http://purl.org/linguistics/gold/hypernym': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Extension'}],
#   'http://dbpedia.org/property/v': [{'type': 'literal',
#     'value': 'no',
#     'datatype': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString'}]},
#  'http://dbpedia.org/resource/International_Semantic_Web_Conference': {'http://dbpedia.org/ontology/academicDiscipline': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Extended_Semantic_Web_Conference': {'http://dbpedia.org/ontology/academicDiscipline': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Joseph_G._Davis': {'http://dbpedia.org/ontology/field': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Farshad_Fotouhi': {'http://dbpedia.org/ontology/field': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Frank_van_Harmelen': {'http://dbpedia.org/ontology/field': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/David_Karger': {'http://dbpedia.org/ontology/field': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/YAGO_(database)': {'http://dbpedia.org/ontology/genre': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Stardog': {'http://dbpedia.org/ontology/genre': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/AdExtent': {'http://dbpedia.org/ontology/genre': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Mulgara_(software)': {'http://dbpedia.org/ontology/genre': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Jena_(framework)': {'http://dbpedia.org/ontology/genre': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Sesame_(framework)': {'http://dbpedia.org/ontology/genre': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Ontotext': {'http://dbpedia.org/ontology/industry': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Deborah_McGuinness': {'http://dbpedia.org/ontology/knownFor': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Resource_Description_Framework': {'http://dbpedia.org/property/domain': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Schema.org': {'http://dbpedia.org/property/domain': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/RDF_Schema': {'http://dbpedia.org/property/domain': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/RDFa': {'http://dbpedia.org/property/domain': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Amit_Sheth': {'http://dbpedia.org/property/fields': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/RuleML': {'http://dbpedia.org/property/focus': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/N-Triples': {'http://dbpedia.org/property/genre': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/RDF/XML': {'http://dbpedia.org/property/genre': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/TriG_(syntax)': {'http://dbpedia.org/property/genre': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Turtle_(syntax)': {'http://dbpedia.org/property/genre': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/TriX_(syntax)': {'http://dbpedia.org/property/genre': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Notation3': {'http://dbpedia.org/property/genre': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Semantic_internet': {'http://dbpedia.org/ontology/wikiPageRedirects': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Semantic_integrity': {'http://dbpedia.org/ontology/wikiPageRedirects': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/The_semantic_web': {'http://dbpedia.org/ontology/wikiPageRedirects': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Web_3': {'http://dbpedia.org/ontology/wikiPageRedirects': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Semantic-web': {'http://dbpedia.org/ontology/wikiPageRedirects': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]},
#  'http://dbpedia.org/resource/Semweb': {'http://dbpedia.org/ontology/wikiPageRedirects': [{'type': 'uri',
#     'value': 'http://dbpedia.org/resource/Semantic_Web'}]}}
